# %% [markdown]
# # Oscar Award Dataset exploration
# ## 1. Which films have won the most awards
# ## 2. Which actors & actresses have won the most awards
# ## 3. At each year, which films have the most nominations and awards?

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
oscar_df = pd.read_csv('../src/datasets/the_oscar_award.csv')

# %%
oscar_df
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
#                       name              film  winner
# 0      Richard Barthelmess         The Noose   False
# 1            Emil Jannings  The Last Command    True
# 2           Louise Dresser   A Ship Comes In   False
# 3             Janet Gaynor        7th Heaven    True
# 4           Gloria Swanson    Sadie Thompson   False
# ...                    ...               ...     ...
# 10390             Parasite          Parasite    True
# 10391          Geena Davis               NaN    True
# 10392          David Lynch               NaN    True
# 10393            Wes Studi               NaN    True
# 10394      Lina Wertmüller               NaN    True
#
# [10395 rows x 7 columns]

# %%
# taking a peek at unique award categories
oscar_df.category.unique()
# Out:
# array(['ACTOR', 'ACTRESS', 'ART DIRECTION', 'CINEMATOGRAPHY',
#        'DIRECTING (Comedy Picture)', 'DIRECTING (Dramatic Picture)',
#        'ENGINEERING EFFECTS', 'OUTSTANDING PICTURE',
#        'UNIQUE AND ARTISTIC PICTURE', 'WRITING (Adaptation)',
#        'WRITING (Original Story)', 'WRITING (Title Writing)',
#        'SPECIAL AWARD', 'DIRECTING', 'WRITING', 'OUTSTANDING PRODUCTION',
#        'SOUND RECORDING', 'SHORT SUBJECT (Cartoon)',
#        'SHORT SUBJECT (Comedy)', 'SHORT SUBJECT (Novelty)',
#        'ASSISTANT DIRECTOR', 'FILM EDITING', 'MUSIC (Scoring)',
#        'MUSIC (Song)', 'DANCE DIRECTION', 'WRITING (Screenplay)',
#        'ACTOR IN A SUPPORTING ROLE', 'ACTRESS IN A SUPPORTING ROLE',
#        'SHORT SUBJECT (Color)', 'SHORT SUBJECT (One-reel)',
#        'SHORT SUBJECT (Two-reel)', 'IRVING G. THALBERG MEMORIAL AWARD',
#        'MUSIC (Original Score)', 'CINEMATOGRAPHY (Black-and-White)',
#        'CINEMATOGRAPHY (Color)', 'SPECIAL EFFECTS',
#        'ART DIRECTION (Black-and-White)', 'ART DIRECTION (Color)',
#        'WRITING (Original Screenplay)', 'DOCUMENTARY (Short Subject)',
#        'MUSIC (Music Score of a Dramatic Picture)',
#        'MUSIC (Scoring of a Musical Picture)',
#        'OUTSTANDING MOTION PICTURE', 'DOCUMENTARY',
#        'MUSIC (Music Score of a Dramatic or Comedy Picture)',
#        'WRITING (Original Motion Picture Story)', 'DOCUMENTARY (Feature)',
#        'BEST MOTION PICTURE', 'WRITING (Motion Picture Story)',
#        'COSTUME DESIGN (Black-and-White)', 'COSTUME DESIGN (Color)',
#        'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'WRITING (Story and Screenplay)',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'FOREIGN LANGUAGE FILM', 'WRITING (Screenplay--Adapted)',
#        'WRITING (Screenplay--Original)',
#        'JEAN HERSHOLT HUMANITARIAN AWARD', 'COSTUME DESIGN',
#        'SHORT SUBJECT (Live Action)',
#        'WRITING (Screenplay--based on material from another medium)',
#        'WRITING (Story and Screenplay--written directly for the screen)',
#        'SOUND', 'MUSIC (Music Score--substantially original)',
#        'MUSIC (Scoring of Music--adaptation or treatment)',
#        'BEST PICTURE', 'SOUND EFFECTS', 'SPECIAL VISUAL EFFECTS',
#        'MUSIC (Original Music Score)',
#        'MUSIC (Original Score--for a motion picture [not a musical])',
#        'MUSIC (Score of a Musical Picture--original or adaptation)',
#        'MUSIC (Song--Original for the Picture)',
#        'WRITING (Story and Screenplay--based on material not previously published or produced)',
#        'MUSIC (Original Song Score)',
#        'WRITING (Story and Screenplay--based on factual material or material not previously published or produced)',
#        'MUSIC (Original Dramatic Score)',
#        'MUSIC (Scoring: Adaptation and Original Song Score)',
#        'SHORT SUBJECT (Animated)',
#        'SPECIAL ACHIEVEMENT AWARD (Visual Effects)',
#        'MUSIC (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)',
#        'SHORT FILM (Animated)', 'SHORT FILM (Live Action)',
#        'WRITING (Screenplay Adapted from Other Material)',
#        'MUSIC (Original Song)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects)',
#        'ACTOR IN A LEADING ROLE', 'ACTRESS IN A LEADING ROLE',
#        'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)',
#        'WRITING (Screenplay Written Directly for the Screen--based on factual material or on story material not previously published or produced)',
#        'VISUAL EFFECTS', 'SPECIAL ACHIEVEMENT AWARD',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects Editing)',
#        'MUSIC (Adaptation Score)',
#        'WRITING (Screenplay Based on Material from Another Medium)',
#        'WRITING (Screenplay Written Directly for the Screen)',
#        'MUSIC (Original Song Score and Its Adaptation -or- Adaptation Score)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Editing)',
#        'SHORT FILM (Dramatic Live Action)', 'MAKEUP',
#        'SOUND EFFECTS EDITING',
#        'MUSIC (Original Song Score or Adaptation Score)',
#        'WRITING (Screenplay Based on Material Previously Produced or Published)',
#        'MUSIC (Original Musical or Comedy Score)', 'SOUND EDITING',
#        'ANIMATED FEATURE FILM', 'WRITING (Adapted Screenplay)',
#        'SOUND MIXING', 'MAKEUP AND HAIRSTYLING', 'PRODUCTION DESIGN',
#        'INTERNATIONAL FEATURE FILM'], dtype=object)

# %%
oscar_df['film'] = oscar_df['film'] + " (" + oscar_df['year_film'].astype(str) + ")"
oscar_df
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
#                       name                     film  winner
# 0      Richard Barthelmess         The Noose (1927)   False
# 1            Emil Jannings  The Last Command (1927)    True
# 2           Louise Dresser   A Ship Comes In (1927)   False
# 3             Janet Gaynor        7th Heaven (1927)    True
# 4           Gloria Swanson    Sadie Thompson (1927)   False
# ...                    ...                      ...     ...
# 10390             Parasite          Parasite (2019)    True
# 10391          Geena Davis                      NaN    True
# 10392          David Lynch                      NaN    True
# 10393            Wes Studi                      NaN    True
# 10394      Lina Wertmüller                      NaN    True
#
# [10395 rows x 7 columns]

# %% [markdown]
# ## 1. Film Nomations and wins

# %%
oscar_df['film'].value_counts()
# Out:
# Titanic (1997)                      14
# All about Eve (1950)                14
# La La Land (2016)                   14
# The Shape of Water (2017)           13
# Gone with the Wind (1939)           13
#                                     ..
# Suzy (1936)                          1
# Paris--Underground (1945)            1
# Sing (2016)                          1
# Snow Falling on Cedars (1999)        1
# The Invisible Man Returns (1940)     1
# Name: film, Length: 4934, dtype: int64

# %%
win_df = oscar_df[(oscar_df.winner == True)]
win_df['film'].value_counts()
# Out:
# Ben-Hur (1959)                                               11
# The Lord of the Rings: The Return of the King (2003)         11
# Titanic (1997)                                               11
# West Side Story (1961)                                       10
# The English Patient (1996)                                    9
#                                                              ..
# The Sand Castle (1977)                                        1
# Wonder Man (1945)                                             1
# My Mother Dreams the Satan's Disciples in New York (1999)     1
# Moscow Strikes Back (1942)                                    1
# Exodus (1960)                                                 1
# Name: film, Length: 1286, dtype: int64

# %%
oscar_df['film'][(oscar_df.winner == True)].value_counts()
# Out:
# Ben-Hur (1959)                                               11
# The Lord of the Rings: The Return of the King (2003)         11
# Titanic (1997)                                               11
# West Side Story (1961)                                       10
# The English Patient (1996)                                    9
#                                                              ..
# The Sand Castle (1977)                                        1
# Wonder Man (1945)                                             1
# My Mother Dreams the Satan's Disciples in New York (1999)     1
# Moscow Strikes Back (1942)                                    1
# Exodus (1960)                                                 1
# Name: film, Length: 1286, dtype: int64

# %%
films_df = pd.DataFrame({'count':oscar_df['film'].value_counts()})

# %%
nominated_films = pd.DataFrame(oscar_df.film.value_counts().reset_index())
nominated_films.columns = ['film', 'nominated']

# %%
nominated_films.head(10)
# Out:
#                                                 film  nominated
# 0                                     Titanic (1997)         14
# 1                               All about Eve (1950)         14
# 2                                  La La Land (2016)         14
# 3                          The Shape of Water (2017)         13
# 4                          Gone with the Wind (1939)         13
# 5                                Mary Poppins (1964)         13
# 6                                Forrest Gump (1994)         13
# 7         The Curious Case of Benjamin Button (2008)         13
# 8  The Lord of the Rings: The Fellowship of the R...         13
# 9             Who's Afraid of Virginia Woolf? (1966)         13

# %%
top_10_nominated = nominated_films.head(10)['film'].to_list()
print(top_10_nominated)
# Out:
# ['Titanic (1997)', 'All about Eve (1950)', 'La La Land (2016)', 'The Shape of Water (2017)', 'Gone with the Wind (1939)', 'Mary Poppins (1964)', 'Forrest Gump (1994)', 'The Curious Case of Benjamin Button (2008)', 'The Lord of the Rings: The Fellowship of the Ring (2001)', "Who's Afraid of Virginia Woolf? (1966)"]

# %%
awarded_films = pd.DataFrame(oscar_df.film[(oscar_df.winner == True)].value_counts().reset_index())
awarded_films.columns = ['film', 'won']
awarded_films['won'].fillna(0, inplace=True)

# %%
top_10_awarded = awarded_films.head(10)['film'].to_list()
print(top_10_awarded)
# Out:
# ['Ben-Hur (1959)', 'The Lord of the Rings: The Return of the King (2003)', 'Titanic (1997)', 'West Side Story (1961)', 'The English Patient (1996)', 'The Last Emperor (1987)', 'Gigi (1958)', 'My Fair Lady (1964)', 'Amadeus (1984)', 'Gone with the Wind (1939)']

# %%
awarded_films.to_csv("../src/datasets/awarded_only_films.csv")

# %%
merged_df = pd.merge(nominated_films, awarded_films, on='film',how = 'outer')

# %%
merged_df['won'].fillna(0, inplace=True)
merged_df['won']=pd.to_numeric(merged_df['won'], downcast='integer')
merged_df['nominated']=pd.to_numeric(merged_df['nominated'], downcast='integer')
merged_df
# Out:
#                                   film  nominated  won
# 0                       Titanic (1997)         14   11
# 1                 All about Eve (1950)         14    6
# 2                    La La Land (2016)         14    6
# 3            The Shape of Water (2017)         13    4
# 4            Gone with the Wind (1939)         13    8
# ...                                ...        ...  ...
# 4929                       Suzy (1936)          1    0
# 4930         Paris--Underground (1945)          1    0
# 4931                       Sing (2016)          1    1
# 4932     Snow Falling on Cedars (1999)          1    0
# 4933  The Invisible Man Returns (1940)          1    0
#
# [4934 rows x 3 columns]

# %%
merged_df.to_csv("../src/datasets/nominated_films.csv")

# %%
# just double check if there are any NA values
df1 = merged_df[merged_df.isna().any(axis=1)]
df1
# Out:
# Empty DataFrame
# Columns: [film, nominated, won]
# Index: []

# %%
# getting all fields just for top 10
top_10_awarded_df = oscar_df[oscar_df['film'].isin(top_10_awarded)]
top_10_nominated_df = oscar_df[oscar_df['film'].isin(top_10_nominated)]

# %%
top_10_awarded_df
# Out:
#       year_film  year_ceremony  ceremony                      category  \
# 785        1939           1940        12                         ACTOR
# 798        1939           1940        12                       ACTRESS
# 799        1939           1940        12  ACTRESS IN A SUPPORTING ROLE
# 801        1939           1940        12  ACTRESS IN A SUPPORTING ROLE
# 807        1939           1940        12                 ART DIRECTION
# ...         ...            ...       ...                           ...
# 8411       2003           2004        76         MUSIC (Original Song)
# 8415       2003           2004        76                  BEST PICTURE
# 8434       2003           2004        76                  SOUND MIXING
# 8438       2003           2004        76                VISUAL EFFECTS
# 8443       2003           2004        76  WRITING (Adapted Screenplay)
#
#                                                name  \
# 785                                     Clark Gable
# 798                                    Vivien Leigh
# 799                             Olivia de Havilland
# 801                                 Hattie McDaniel
# 807                              Gone with the Wind
# ...                                             ...
# 8411  The Lord of the Rings: The Return of the King
# 8415  The Lord of the Rings: The Return of the King
# 8434  The Lord of the Rings: The Return of the King
# 8438  The Lord of the Rings: The Return of the King
# 8443  The Lord of the Rings: The Return of the King
#
#                                                    film  winner
# 785                           Gone with the Wind (1939)   False
# 798                           Gone with the Wind (1939)    True
# 799                           Gone with the Wind (1939)   False
# 801                           Gone with the Wind (1939)    True
# 807                           Gone with the Wind (1939)    True
# ...                                                 ...     ...
# 8411  The Lord of the Rings: The Return of the King ...    True
# 8415  The Lord of the Rings: The Return of the King ...    True
# 8434  The Lord of the Rings: The Return of the King ...    True
# 8438  The Lord of the Rings: The Return of the King ...    True
# 8443  The Lord of the Rings: The Return of the King ...    True
#
# [114 rows x 7 columns]

# %%
top_10_nominated_df
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 785         1939           1940        12                          ACTOR
# 798         1939           1940        12                        ACTRESS
# 799         1939           1940        12   ACTRESS IN A SUPPORTING ROLE
# 801         1939           1940        12   ACTRESS IN A SUPPORTING ROLE
# 807         1939           1940        12                  ART DIRECTION
# ...          ...            ...       ...                            ...
# 10095       2017           2018        90                   BEST PICTURE
# 10101       2017           2018        90              PRODUCTION DESIGN
# 10115       2017           2018        90                  SOUND EDITING
# 10120       2017           2018        90                   SOUND MIXING
# 10135       2017           2018        90  WRITING (Original Screenplay)
#
#                       name                       film  winner
# 785            Clark Gable  Gone with the Wind (1939)   False
# 798           Vivien Leigh  Gone with the Wind (1939)    True
# 799    Olivia de Havilland  Gone with the Wind (1939)   False
# 801        Hattie McDaniel  Gone with the Wind (1939)    True
# 807     Gone with the Wind  Gone with the Wind (1939)    True
# ...                    ...                        ...     ...
# 10095   The Shape of Water  The Shape of Water (2017)    True
# 10101   The Shape of Water  The Shape of Water (2017)    True
# 10115   The Shape of Water  The Shape of Water (2017)   False
# 10120   The Shape of Water  The Shape of Water (2017)   False
# 10135   The Shape of Water  The Shape of Water (2017)   False
#
# [133 rows x 7 columns]

# %%
top_10_nominated_df.to_csv('../src/datasets/top_10_nominated.csv')
top_10_awarded_df.to_csv('../src/datasets/top_10_awarded.csv')

# %% [markdown]
# ## 2. Actors and Actresses

# %%
actor_df = oscar_df.loc[oscar_df.category == 'ACTOR']
actor_df
# Out:
#       year_film  year_ceremony  ceremony category                 name  \
# 0          1927           1928         1    ACTOR  Richard Barthelmess
# 1          1927           1928         1    ACTOR        Emil Jannings
# 35         1928           1929         2    ACTOR      George Bancroft
# 36         1928           1929         2    ACTOR        Warner Baxter
# 37         1928           1929         2    ACTOR       Chester Morris
# ...         ...            ...       ...      ...                  ...
# 5298       1975           1976        48    ACTOR       Walter Matthau
# 5299       1975           1976        48    ACTOR       Jack Nicholson
# 5300       1975           1976        48    ACTOR            Al Pacino
# 5301       1975           1976        48    ACTOR    Maximilian Schell
# 5302       1975           1976        48    ACTOR       James Whitmore
#
#                                         film  winner
# 0                           The Noose (1927)   False
# 1                    The Last Command (1927)    True
# 35                        Thunderbolt (1928)   False
# 36                     In Old Arizona (1928)    True
# 37                              Alibi (1928)   False
# ...                                      ...     ...
# 5298                The Sunshine Boys (1975)   False
# 5299  One Flew over the Cuckoo's Nest (1975)    True
# 5300                Dog Day Afternoon (1975)   False
# 5301       The Man in the Glass Booth (1975)   False
# 5302            Give 'em Hell, Harry! (1975)   False
#
# [232 rows x 7 columns]

# %%
actress_df = oscar_df.loc[oscar_df.category == 'ACTRESS']
actress_df
# Out:
#       year_film  year_ceremony  ceremony category             name  \
# 2          1927           1928         1  ACTRESS   Louise Dresser
# 3          1927           1928         1  ACTRESS     Janet Gaynor
# 4          1927           1928         1  ACTRESS   Gloria Swanson
# 40         1928           1929         2  ACTRESS  Ruth Chatterton
# 41         1928           1929         2  ACTRESS    Betty Compson
# ...         ...            ...       ...      ...              ...
# 5308       1975           1976        48  ACTRESS  Isabelle Adjani
# 5309       1975           1976        48  ACTRESS      Ann-Margret
# 5310       1975           1976        48  ACTRESS  Louise Fletcher
# 5311       1975           1976        48  ACTRESS   Glenda Jackson
# 5312       1975           1976        48  ACTRESS       Carol Kane
#
#                                         film  winner
# 2                     A Ship Comes In (1927)   False
# 3                          7th Heaven (1927)    True
# 4                      Sadie Thompson (1927)   False
# 40                           Madame X (1928)   False
# 41                         The Barker (1928)   False
# ...                                      ...     ...
# 5308            The Story of Adele H. (1975)   False
# 5309                            Tommy (1975)   False
# 5310  One Flew over the Cuckoo's Nest (1975)    True
# 5311                            Hedda (1975)   False
# 5312                    Hester Street (1975)   False
#
# [236 rows x 7 columns]

# %%
actor_supporting_df = oscar_df.loc[oscar_df.category == 'ACTOR IN A SUPPORTING ROLE']
actor_supporting_df
# Out:
#        year_film  year_ceremony  ceremony                    category  \
# 420         1936           1937         9  ACTOR IN A SUPPORTING ROLE
# 421         1936           1937         9  ACTOR IN A SUPPORTING ROLE
# 422         1936           1937         9  ACTOR IN A SUPPORTING ROLE
# 423         1936           1937         9  ACTOR IN A SUPPORTING ROLE
# 424         1936           1937         9  ACTOR IN A SUPPORTING ROLE
# ...          ...            ...       ...                         ...
# 10272       2019           2020        92  ACTOR IN A SUPPORTING ROLE
# 10273       2019           2020        92  ACTOR IN A SUPPORTING ROLE
# 10274       2019           2020        92  ACTOR IN A SUPPORTING ROLE
# 10275       2019           2020        92  ACTOR IN A SUPPORTING ROLE
# 10276       2019           2020        92  ACTOR IN A SUPPORTING ROLE
#
#                   name                                        film  winner
# 420        Mischa Auer                       My Man Godfrey (1936)   False
# 421     Walter Brennan                      Come and Get It (1936)    True
# 422       Stuart Erwin                       Pigskin Parade (1936)   False
# 423     Basil Rathbone                     Romeo and Juliet (1936)   False
# 424      Akim Tamiroff             The General Died at Dawn (1936)   False
# ...                ...                                         ...     ...
# 10272        Tom Hanks  A Beautiful Day in the Neighborhood (2019)   False
# 10273  Anthony Hopkins                        The Two Popes (2019)   False
# 10274        Al Pacino                         The Irishman (2019)   False
# 10275        Joe Pesci                         The Irishman (2019)   False
# 10276        Brad Pitt      Once upon a Time...in Hollywood (2019)    True
#
# [420 rows x 7 columns]

# %%
actress_supporting_df = oscar_df.loc[oscar_df.category == 'ACTRESS IN A SUPPORTING ROLE']
actress_supporting_df
# Out:
#        year_film  year_ceremony  ceremony                      category  \
# 430         1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 431         1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 432         1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 433         1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 434         1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# ...          ...            ...       ...                           ...
# 10282       2019           2020        92  ACTRESS IN A SUPPORTING ROLE
# 10283       2019           2020        92  ACTRESS IN A SUPPORTING ROLE
# 10284       2019           2020        92  ACTRESS IN A SUPPORTING ROLE
# 10285       2019           2020        92  ACTRESS IN A SUPPORTING ROLE
# 10286       2019           2020        92  ACTRESS IN A SUPPORTING ROLE
#
#                      name                       film  winner
# 430          Beulah Bondi  The Gorgeous Hussy (1936)   False
# 431           Alice Brady      My Man Godfrey (1936)   False
# 432      Bonita Granville         These Three (1936)   False
# 433     Maria Ouspenskaya           Dodsworth (1936)   False
# 434      Gale Sondergaard     Anthony Adverse (1936)    True
# ...                   ...                        ...     ...
# 10282         Kathy Bates      Richard Jewell (2019)   False
# 10283          Laura Dern      Marriage Story (2019)    True
# 10284  Scarlett Johansson         Jojo Rabbit (2019)   False
# 10285       Florence Pugh        Little Women (2019)   False
# 10286       Margot Robbie           Bombshell (2019)   False
#
# [420 rows x 7 columns]

# %%
actor_df.to_csv('../src/datasets/actor.csv')
actor_supporting_df.to_csv('../src/datasets/actor.csv')
actress_df.to_csv('../src/datasets/actress.csv')
actress_supporting_df.to_csv('../src/datasets/actress_supporting.csv')
